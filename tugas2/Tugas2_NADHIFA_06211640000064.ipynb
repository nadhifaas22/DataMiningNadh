# %% [markdown]
# # Tugas Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('travel-times.csv')

# %%
data = data.drop('Comments', 1)

# %%
#ukuran tabel
data.shape
# Out:
# (205, 12)

# %%
#5 data teratas
data.head(n=5)
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012      8:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012      7:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Take407All
# 0            84.8          NaN       39.3        36.3         No
# 1            88.9          NaN       37.9        34.9         No
# 2            85.8          NaN       37.5        35.9         No
# 3            82.9          NaN       39.8        35.6         No
# 4            88.1          NaN       36.8        34.8         No

# %%
#5 data terbawah
data.tail(n=5)
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 200  7/18/2011      8:09     Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011      8:03   Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08  Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    Home     51.73     125.0      62.8
#
#      AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Take407All
# 200            82.4         7.89       65.5        39.7         No
# 201            95.1         7.89       40.1        32.1        Yes
# 202            76.7          NaN       54.2        40.6        Yes
# 203            87.6          NaN       51.9        36.5        Yes
# 204            92.5          NaN       49.5        33.6        Yes

# %%
data.describe() #descriptive statistics buat data numerik
# Out:
#          Distance    MaxSpeed    AvgSpeed  AvgMovingSpeed  FuelEconomy  \
# count  205.000000  205.000000  205.000000      205.000000   186.000000
# mean    50.981512  127.591707   74.477561       81.975610     8.690591
# std      1.321205    4.128450   11.409816       10.111544     0.504971
# min     48.320000  112.200000   38.100000       50.300000     7.810000
# 25%     50.650000  124.900000   68.900000       76.600000     8.370000
# 50%     51.140000  127.400000   73.600000       81.400000     8.520000
# 75%     51.630000  129.800000   79.900000       86.000000     8.970000
# max     60.320000  140.900000  107.700000      112.100000    10.050000
#
#         TotalTime  MovingTime
# count  205.000000  205.000000
# mean    41.904390   37.871707
# std      6.849476    4.835072
# min     28.200000   27.100000
# 25%     38.400000   35.700000
# 50%     41.300000   37.600000
# 75%     44.400000   39.900000
# max     82.300000   62.400000

# %%
#untuk menghitung satu kolom
data['Take407All'].value_counts()
# Out:
# No     164
# Yes     35
# Name: Take407All, dtype: int64

# %%
data['DayOfWeek'].value_counts()
# Out:
# Tuesday      48
# Wednesday    47
# Thursday     44
# Monday       39
# Friday       27
# Name: DayOfWeek, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 12 columns):
# Date              205 non-null object
# StartTime         205 non-null object
# DayOfWeek         205 non-null object
# GoingTo           205 non-null object
# Distance          205 non-null float64
# MaxSpeed          205 non-null float64
# AvgSpeed          205 non-null float64
# AvgMovingSpeed    205 non-null float64
# FuelEconomy       186 non-null float64
# TotalTime         205 non-null float64
# MovingTime        205 non-null float64
# Take407All        199 non-null object
# dtypes: float64(7), object(5)
# memory usage: 19.3+ KB

# %% [markdown]
# ## Imputation Missing Value

# %%
np.sum(data.isnull()) #number of NA for each variable
# Out:
# Date               0
# StartTime          0
# DayOfWeek          0
# GoingTo            0
# Distance           0
# MaxSpeed           0
# AvgSpeed           0
# AvgMovingSpeed     0
# FuelEconomy       19
# TotalTime          0
# MovingTime         0
# Take407All         6
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 25

# %%
data['FuelEconomy'] = data['FuelEconomy'].fillna((data['FuelEconomy'].mean()))
data['Take407All'] = data.fillna(data['Take407All'].value_counts().index[0])
data.isnull().any()
# Out:
# Date              False
# StartTime         False
# DayOfWeek         False
# GoingTo           False
# Distance          False
# MaxSpeed          False
# AvgSpeed          False
# AvgMovingSpeed    False
# FuelEconomy       False
# TotalTime         False
# MovingTime        False
# Take407All        False
# dtype: bool

# %% [markdown]
# ## Encode Labels

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012      8:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012      7:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Take407All
# 0            84.8     8.690591       39.3        36.3   1/6/2012
# 1            88.9     8.690591       37.9        34.9   1/6/2012
# 2            85.8     8.690591       37.5        35.9   1/4/2012
# 3            82.9     8.690591       39.8        35.6   1/4/2012
# 4            88.1     8.690591       36.8        34.8   1/3/2012

# %%
data['DayOfWeek'] = LabelEncoder().fit_transform(data['DayOfWeek'])
data['GoingTo'] = LabelEncoder().fit_transform(data['GoingTo'])
data['Take407All'] = LabelEncoder().fit_transform(data['Take407All'])
data.head()
# Out:
#        Date StartTime  DayOfWeek  GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37          0        1     51.29     127.4      78.3
# 1  1/6/2012      8:20          0        0     51.63     130.3      81.8
# 2  1/4/2012     16:17          4        1     51.27     127.4      82.0
# 3  1/4/2012      7:53          4        0     49.17     132.3      74.2
# 4  1/3/2012     18:57          3        1     51.15     136.2      83.4
#
#    AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime  Take407All
# 0            84.8     8.690591       39.3        36.3           3
# 1            88.9     8.690591       37.9        34.9           3
# 2            85.8     8.690591       37.5        35.9           2
# 3            82.9     8.690591       39.8        35.6           2
# 4            88.1     8.690591       36.8        34.8           1

# %% [markdown]
# ## Standardize

# %%
from sklearn.preprocessing import StandardScaler

# %%
#standardize hanya untuk data numerik
data['Distance'] = StandardScaler().fit(data[['Distance']]).transform(data[['Distance']])
data['MaxSpeed'] = StandardScaler().fit(data[['MaxSpeed']]).transform(data[['MaxSpeed']])
data['AvgSpeed'] = StandardScaler().fit(data[['AvgSpeed']]).transform(data[['AvgSpeed']])
data['AvgMovingSpeed'] = StandardScaler().fit(data[['AvgMovingSpeed']]).transform(data[['AvgMovingSpeed']])
data['FuelEconomy'] = StandardScaler().fit(data[['FuelEconomy']]).transform(data[['FuelEconomy']])
data.head()
# Out:
#        Date StartTime  DayOfWeek  GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37          0        1  0.234061 -0.046549  0.335833
# 1  1/6/2012      8:20          0        0  0.492032  0.657613  0.643338
# 2  1/4/2012     16:17          4        1  0.218887 -0.046549  0.660909
# 3  1/4/2012      7:53          4        0 -1.374462  1.143242 -0.024386
# 4  1/3/2012     18:57          3        1  0.127838  2.090219  0.783911
#
#    AvgMovingSpeed   FuelEconomy  TotalTime  MovingTime  Take407All
# 0        0.280007 -3.703009e-15       39.3        36.3           3
# 1        0.686477 -3.703009e-15       37.9        34.9           3
# 2        0.379146 -3.703009e-15       37.5        35.9           2
# 3        0.091643 -3.703009e-15       39.8        35.6           2
# 4        0.607166 -3.703009e-15       36.8        34.8           1

# %% [markdown]
# ## Normalize

# %%
from sklearn.preprocessing import Normalizer

# %%
#normalize hanya untuk data numerik
data['Distance'] = Normalizer().fit(data[['Distance']]).transform(data[['Distance']])
data['MaxSpeed'] = Normalizer().fit(data[['MaxSpeed']]).transform(data[['MaxSpeed']])
data['AvgSpeed'] = Normalizer().fit(data[['AvgSpeed']]).transform(data[['AvgSpeed']])
data['AvgMovingSpeed'] = Normalizer().fit(data[['AvgMovingSpeed']]).transform(data[['AvgMovingSpeed']])
data['FuelEconomy'] = Normalizer().fit(data[['FuelEconomy']]).transform(data[['FuelEconomy']])
data['TotalTime'] = Normalizer().fit(data[['TotalTime']]).transform(data[['TotalTime']])
data['MovingTime'] = Normalizer().fit(data[['MovingTime']]).transform(data[['MovingTime']])
data.head()
# Out:
#        Date StartTime  DayOfWeek  GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37          0        1       1.0      -1.0       1.0
# 1  1/6/2012      8:20          0        0       1.0       1.0       1.0
# 2  1/4/2012     16:17          4        1       1.0      -1.0       1.0
# 3  1/4/2012      7:53          4        0      -1.0       1.0      -1.0
# 4  1/3/2012     18:57          3        1       1.0       1.0       1.0
#
#    AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime  Take407All
# 0             1.0         -1.0        1.0         1.0           3
# 1             1.0         -1.0        1.0         1.0           3
# 2             1.0         -1.0        1.0         1.0           2
# 3             1.0         -1.0        1.0         1.0           2
# 4             1.0         -1.0        1.0         1.0           1
